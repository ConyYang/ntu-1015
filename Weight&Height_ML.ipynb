# %%
# Basic Libraries
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt # we only need pyplot
sb.set() # set the default Seaborn style for graphics

import plotly.offline as py
import plotly.figure_factory as ff
import plotly.graph_objs as go
from plotly import tools
# Activate inline plotting in notebook
py.init_notebook_mode(connected = False)
olympic = pd.read_csv('/Users/yangyubei/Documents/YangYubei/athlete_events.csv')

regions = pd.read_csv('/Users/yangyubei/Documents/YangYubei/noc_regions.csv')
olympicData = pd.merge(olympic, regions, on='NOC', how='left')

# %%
#1
Atheletics_F_win= pd.DataFrame(olympicData[["NOC", "Year","Sex","Sport","Medal","Height","Weight"]]
                     [olympicData['Year']>=1984]
                     [(olympicData['Medal']=='Gold')|
                            (olympicData['Medal']=='Silver')|
                           (olympicData['Medal']=='Bronze')]
                    [olympicData['Sport'] == 'Athletics']
                    [olympicData['Sex'] == 'F']) 
#2
Swimming_F_win= pd.DataFrame(olympicData[["NOC", "Year","Sex","Sport","Medal","Height","Weight"]]
                     [olympicData['Year']>=1984]
                     [(olympicData['Medal']=='Gold')|
                            (olympicData['Medal']=='Silver')|
                           (olympicData['Medal']=='Bronze')]
                    [olympicData['Sport'] == 'Swimming']
                    [olympicData['Sex'] == 'F'])
#3
Gymnastics_F_win= pd.DataFrame(olympicData[["NOC", "Year","Sex","Sport","Medal","Height","Weight"]]
                     [olympicData['Year']>=1984]
                     [(olympicData['Medal']=='Gold')|
                            (olympicData['Medal']=='Silver')|
                           (olympicData['Medal']=='Bronze')]
                    [olympicData['Sport'] =='Gymnastics']
                    [olympicData['Sex'] == 'F'])
#4
CrossCountrySkilling_F_win= pd.DataFrame(olympicData[["NOC", "Year","Sex","Sport","Medal","Height","Weight"]]
                     [olympicData['Year']>=1984]
                     [(olympicData['Medal']=='Gold')|
                            (olympicData['Medal']=='Silver')|
                           (olympicData['Medal']=='Bronze')]
                    [olympicData['Sport'] =='Cross Country Skiing']
                    [olympicData['Sex'] == 'M'])

#5
AlpineSkiing_F_win= pd.DataFrame(olympicData[["NOC", "Year","Sex","Sport","Medal","Height","Weight"]]
                     [olympicData['Year']>=1984]
                     [(olympicData['Medal']=='Gold')|
                            (olympicData['Medal']=='Silver')|
                           (olympicData['Medal']=='Bronze')]
                    [olympicData['Sport'] =='Alpine Skiing']
                    [olympicData['Sex'] == 'F'])
#6
Cycling_F_win= pd.DataFrame(olympicData[["NOC", "Year","Sex","Sport","Medal","Height","Weight"]]
                     [olympicData['Year']>=1984]
                     [(olympicData['Medal']=='Gold')|
                            (olympicData['Medal']=='Silver')|
                           (olympicData['Medal']=='Bronze')]
                    [olympicData['Sport'] =='Cycling']
                    [olympicData['Sex'] == 'F'])
#7
Rowing_F_win= pd.DataFrame(olympicData[["NOC", "Year","Sex","Sport","Medal","Height","Weight"]]
                     [olympicData['Year']>=1984]
                     [(olympicData['Medal']=='Gold')|
                            (olympicData['Medal']=='Silver')|
                           (olympicData['Medal']=='Bronze')]
                    [olympicData['Sport'] =='Rowing']
                    [olympicData['Sex'] == 'F'])
#8
Shooting_F_win= pd.DataFrame(olympicData[["NOC", "Year","Sex","Sport","Medal","Height","Weight"]]
                     [olympicData['Year']>=1984]
                     [(olympicData['Medal']=='Gold')|
                            (olympicData['Medal']=='Silver')|
                           (olympicData['Medal']=='Bronze')]
                    [olympicData['Sport'] =='Shooting']
                    [olympicData['Sex'] == 'F'])
#9
Biathlon_F_win= pd.DataFrame(olympicData[["NOC", "Year","Sex","Sport","Medal","Height","Weight"]]
                     [olympicData['Year']>=1984]
                     [(olympicData['Medal']=='Gold')|
                            (olympicData['Medal']=='Silver')|
                           (olympicData['Medal']=='Bronze')]
                    [olympicData['Sport'] =='Biathlon']
                    [olympicData['Sex'] == 'F'])
#10
Canoeing_F_win= pd.DataFrame(olympicData[["NOC", "Year","Sex","Sport","Medal","Height","Weight"]]
                     [olympicData['Year']>=1984]
                     [(olympicData['Medal']=='Gold')|
                            (olympicData['Medal']=='Silver')|
                           (olympicData['Medal']=='Bronze')]
                    [olympicData['Sport'] =='Canoeing']
                    [olympicData['Sex'] == 'F'])
#11
Sailing_F_win= pd.DataFrame(olympicData[["NOC", "Year","Sex","Sport","Medal","Height","Weight"]]
                     [olympicData['Year']>=1984]
                     [(olympicData['Medal']=='Gold')|
                            (olympicData['Medal']=='Silver')|
                           (olympicData['Medal']=='Bronze')]
                    [olympicData['Sport'] =='Sailing']
                    [olympicData['Sex'] == 'F'])
#12
Fencing_F_win= pd.DataFrame(olympicData[["NOC", "Year","Sex","Sport","Medal","Height","Weight"]]
                     [olympicData['Year']>=1984]
                     [(olympicData['Medal']=='Gold')|
                            (olympicData['Medal']=='Silver')|
                           (olympicData['Medal']=='Bronze')]
                    [olympicData['Sport'] =='Fencing']
                    [olympicData['Sex'] == 'F'])
#13
Football_F_win= pd.DataFrame(olympicData[["NOC", "Year","Sex","Sport","Medal","Height","Weight"]]
                     [olympicData['Year']>=1984]
                     [(olympicData['Medal']=='Gold')|
                            (olympicData['Medal']=='Silver')|
                           (olympicData['Medal']=='Bronze')]
                    [olympicData['Sport'] =='Football']
                    [olympicData['Sex'] == 'F'])


#14
IceHockey_F_win= pd.DataFrame(olympicData[["NOC", "Year","Sex","Sport","Medal","Height","Weight"]]
                     [olympicData['Year']>=1984]
                     [(olympicData['Medal']=='Gold')|
                            (olympicData['Medal']=='Silver')|
                           (olympicData['Medal']=='Bronze')]
                    [olympicData['Sport'] =='Ice Hockey']
                    [olympicData['Sex'] == 'F'])
#15
Judo_F_win= pd.DataFrame(olympicData[["NOC", "Year","Sex","Sport","Medal","Height","Weight"]]
                     [olympicData['Year']>=1984]
                     [(olympicData['Medal']=='Gold')|
                            (olympicData['Medal']=='Silver')|
                           (olympicData['Medal']=='Bronze')]
                    [olympicData['Sport'] =='Judo']
                    [olympicData['Sex'] == 'F'])
#16
Wrestling_F_win= pd.DataFrame(olympicData[["NOC", "Year","Sex","Sport","Medal","Height","Weight"]]
                     [olympicData['Year']>=1984]
                     [(olympicData['Medal']=='Gold')|
                            (olympicData['Medal']=='Silver')|
                           (olympicData['Medal']=='Bronze')]
                    [olympicData['Sport'] =='Wrestling']
                    [olympicData['Sex'] == 'F'])
#17
SpeedSkating_F_win= pd.DataFrame(olympicData[["NOC", "Year","Sex","Sport","Medal","Height","Weight"]]
                     [olympicData['Year']>=1984]
                     [(olympicData['Medal']=='Gold')|
                            (olympicData['Medal']=='Silver')|
                           (olympicData['Medal']=='Bronze')]
                    [olympicData['Sport'] =='Speed Skating']
                    [olympicData['Sex'] == 'M'])
#18
Hockey_F_win= pd.DataFrame(olympicData[["NOC", "Year","Sex","Sport","Medal","Height","Weight"]]
                     [olympicData['Year']>=1984]
                     [(olympicData['Medal']=='Gold')|
                            (olympicData['Medal']=='Silver')|
                           (olympicData['Medal']=='Bronze')]
                    [olympicData['Sport'] =='Hockey']
                    [olympicData['Sex'] == 'F'])
#19
Equestrianism_F_win= pd.DataFrame(olympicData[["NOC", "Year","Sex","Sport","Medal","Height","Weight"]]
                     [olympicData['Year']>=1984]
                     [(olympicData['Medal']=='Gold')|
                            (olympicData['Medal']=='Silver')|
                           (olympicData['Medal']=='Bronze')]
                    [olympicData['Sport'] =='Equestrianism']
                    [olympicData['Sex'] == 'F'])
#20
Boxing_F_win= pd.DataFrame(olympicData[["NOC", "Year","Sex","Sport","Medal","Height","Weight"]]
                     [olympicData['Year']>=1984]
                     [(olympicData['Medal']=='Gold')|
                            (olympicData['Medal']=='Silver')|
                           (olympicData['Medal']=='Bronze')]
                    [olympicData['Sport'] =='Boxing']
                    [olympicData['Sex'] == 'F'])
#21
Handball_F_win= pd.DataFrame(olympicData[["NOC", "Year","Sex","Sport","Medal","Height","Weight"]]
                     [olympicData['Year']>=1984]
                     [(olympicData['Medal']=='Gold')|
                            (olympicData['Medal']=='Silver')|
                           (olympicData['Medal']=='Bronze')]
                    [olympicData['Sport'] =='Handball']
                    [olympicData['Sex'] == 'F'])
#22
Basketball_F_win= pd.DataFrame(olympicData[["NOC", "Year","Sex","Sport","Medal","Height","Weight"]]
                     [olympicData['Year']>=1984]
                     [(olympicData['Medal']=='Gold')|
                            (olympicData['Medal']=='Silver')|
                           (olympicData['Medal']=='Bronze')]
                    [olympicData['Sport'] =='Basketball']
                    [olympicData['Sex'] == 'F'])
#23
Volleyball_F_win= pd.DataFrame(olympicData[["NOC", "Year","Sex","Sport","Medal","Height","Weight"]]
                     [olympicData['Year']>=1984]
                     [(olympicData['Medal']=='Gold')|
                            (olympicData['Medal']=='Silver')|
                           (olympicData['Medal']=='Bronze')]
                    [olympicData['Sport'] =='Volleyball']
                    [olympicData['Sex'] == 'F'])
#24
Weightlifting_F_win= pd.DataFrame(olympicData[["NOC", "Year","Sex","Sport","Medal","Height","Weight"]]
                     [olympicData['Year']>=1984]
                     [(olympicData['Medal']=='Gold')|
                            (olympicData['Medal']=='Silver')|
                           (olympicData['Medal']=='Bronze')]
                    [olympicData['Sport'] =='Weightlifting']
                    [olympicData['Sex'] == 'F'])
#25
Tennis_F_win= pd.DataFrame(olympicData[["NOC", "Year","Sex","Sport","Medal","Height","Weight"]]
                     [olympicData['Year']>=1984]
                     [(olympicData['Medal']=='Gold')|
                            (olympicData['Medal']=='Silver')|
                           (olympicData['Medal']=='Bronze')]
                    [olympicData['Sport'] =='Tennis']
                    [olympicData['Sex'] == 'F'])

#26
TableTennis_F_win= pd.DataFrame(olympicData[["NOC", "Year","Sex","Sport","Medal","Height","Weight"]]
                     [olympicData['Year']>=1984]
                     [(olympicData['Medal']=='Gold')|
                            (olympicData['Medal']=='Silver')|
                           (olympicData['Medal']=='Bronze')]
                    [olympicData['Sport'] =='Table Tennis']
                    [olympicData['Sex'] == 'F'])
#27
WaterPolo_F_win= pd.DataFrame(olympicData[["NOC", "Year","Sex","Sport","Medal","Height","Weight"]]
                     [olympicData['Year']>=1984]
                     [(olympicData['Medal']=='Gold')|
                            (olympicData['Medal']=='Silver')|
                           (olympicData['Medal']=='Bronze')]
                    [olympicData['Sport'] =='Water Polo']
                    [olympicData['Sex'] == 'F'])
#28
Archery_F_win= pd.DataFrame(olympicData[["NOC", "Year","Sex","Sport","Medal","Height","Weight"]]
                     [olympicData['Year']>=1984]
                     [(olympicData['Medal']=='Gold')|
                            (olympicData['Medal']=='Silver')|
                           (olympicData['Medal']=='Bronze')]
                    [olympicData['Sport'] =='Archery']
                    [olympicData['Sex'] == 'F'])
#29
Bobsleigh_F_win= pd.DataFrame(olympicData[["NOC", "Year","Sex","Sport","Medal","Height","Weight"]]
                     [olympicData['Year']>=1984]
                     [(olympicData['Medal']=='Gold')|
                            (olympicData['Medal']=='Silver')|
                           (olympicData['Medal']=='Bronze')]
                    [olympicData['Sport'] =='Bobsleigh']
                    [olympicData['Sex'] == 'F'])
#30
ShortTrackSpeedSkating_F_win= pd.DataFrame(olympicData[["NOC", "Year","Sex","Sport","Medal","Height","Weight"]]
                     [olympicData['Year']>=1984]
                     [(olympicData['Medal']=='Gold')|
                            (olympicData['Medal']=='Silver')|
                           (olympicData['Medal']=='Bronze')]
                    [olympicData['Sport'] =='Short Track Speed Skating']
                    [olympicData['Sex'] == 'F'])
#31
SkiJumping_F_win= pd.DataFrame(olympicData[["NOC", "Year","Sex","Sport","Medal","Height","Weight"]]
                     [olympicData['Year']>=1984]
                     [(olympicData['Medal']=='Gold')|
                            (olympicData['Medal']=='Silver')|
                           (olympicData['Medal']=='Bronze')]
                    [olympicData['Sport'] =='Ski Jumping']
                    [olympicData['Sex'] == 'F'])
#32
Badminton_F_win= pd.DataFrame(olympicData[["NOC", "Year","Sex","Sport","Medal","Height","Weight"]]
                     [olympicData['Year']>=1984]
                     [(olympicData['Medal']=='Gold')|
                            (olympicData['Medal']=='Silver')|
                           (olympicData['Medal']=='Bronze')]
                    [olympicData['Sport'] =='Badminton']
                    [olympicData['Sex'] == 'F'])
#33
Diving_F_win= pd.DataFrame(olympicData[["NOC", "Year","Sex","Sport","Medal","Height","Weight"]]
                     [olympicData['Year']>=1984]
                     [(olympicData['Medal']=='Gold')|
                            (olympicData['Medal']=='Silver')|
                           (olympicData['Medal']=='Bronze')]
                    [olympicData['Sport'] =='Diving']
                    [olympicData['Sex'] == 'F'])
#34
FigureSkating_F_win= pd.DataFrame(olympicData[["NOC", "Year","Sex","Sport","Medal","Height","Weight"]]
                     [olympicData['Year']>=1984]
                     [(olympicData['Medal']=='Gold')|
                            (olympicData['Medal']=='Silver')|
                           (olympicData['Medal']=='Bronze')]
                    [olympicData['Sport'] =='Figure Skating']
                    [olympicData['Sex'] == 'F'])
#35
Luge_F_win= pd.DataFrame(olympicData[["NOC", "Year","Sex","Sport","Medal","Height","Weight"]]
                     [olympicData['Year']>=1984]
                     [(olympicData['Medal']=='Gold')|
                            (olympicData['Medal']=='Silver')|
                           (olympicData['Medal']=='Bronze')]
                    [olympicData['Sport'] =='Luge']
                    [olympicData['Sex'] == 'F'])
#36
FreestyleSkiing_F_win= pd.DataFrame(olympicData[["NOC", "Year","Sex","Sport","Medal","Height","Weight"]]
                     [olympicData['Year']>=1984]
                     [(olympicData['Medal']=='Gold')|
                            (olympicData['Medal']=='Silver')|
                           (olympicData['Medal']=='Bronze')]
                    [olympicData['Sport'] =='Freestyle Skiing']
                    [olympicData['Sex'] == 'F'])
#37
Snowboading_F_win= pd.DataFrame(olympicData[["NOC", "Year","Sex","Sport","Medal","Height","Weight"]]
                     [olympicData['Year']>=1984]
                     [(olympicData['Medal']=='Gold')|
                            (olympicData['Medal']=='Silver')|
                           (olympicData['Medal']=='Bronze')]
                    [olympicData['Sport'] =='Snowboarding']
                    [olympicData['Sex'] == 'F'])
#38
SynchronizedSwimming_F_win= pd.DataFrame(olympicData[["NOC", "Year","Sex","Sport","Medal","Height","Weight"]]
                     [olympicData['Year']>=1984]
                     [(olympicData['Medal']=='Gold')|
                            (olympicData['Medal']=='Silver')|
                           (olympicData['Medal']=='Bronze')]
                    [olympicData['Sport'] =='Synchronized Swimming']
                    [olympicData['Sex'] == 'F'])
#39
Baseball_F_win= pd.DataFrame(olympicData[["NOC", "Year","Sex","Sport","Medal","Height","Weight"]]
                     [olympicData['Year']>=1984]
                     [(olympicData['Medal']=='Gold')|
                            (olympicData['Medal']=='Silver')|
                           (olympicData['Medal']=='Bronze')]
                    [olympicData['Sport'] =='Baseball']
                    [olympicData['Sex'] == 'F'])
#40
NordicCombined_F_win= pd.DataFrame(olympicData[["NOC", "Year","Sex","Sport","Medal","Height","Weight"]]
                     [olympicData['Year']>=1984]
                     [(olympicData['Medal']=='Gold')|
                            (olympicData['Medal']=='Silver')|
                           (olympicData['Medal']=='Bronze')]
                    [olympicData['Sport'] =='Nordic Combined']
                    [olympicData['Sex'] == 'F'])
#41
MordernPentathlon_F_win= pd.DataFrame(olympicData[["NOC", "Year","Sex","Sport","Medal","Height","Weight"]]
                     [olympicData['Year']>=1984]
                     [(olympicData['Medal']=='Gold')|
                            (olympicData['Medal']=='Silver')|
                           (olympicData['Medal']=='Bronze')]
                    [olympicData['Sport'] =='Modern Pentathlon']
                    [olympicData['Sex'] == 'F'])
#42
RhythmicGymnastics_F_win= pd.DataFrame(olympicData[["NOC", "Year","Sex","Sport","Medal","Height","Weight"]]
                     [olympicData['Year']>=1984]
                     [(olympicData['Medal']=='Gold')|
                            (olympicData['Medal']=='Silver')|
                           (olympicData['Medal']=='Bronze')]
                    [olympicData['Sport'] =='Rhythmic Gymnastics']
                    [olympicData['Sex'] == 'F'])
#43
Taekwondo_F_win= pd.DataFrame(olympicData[["NOC", "Year","Sex","Sport","Medal","Height","Weight"]]
                     [olympicData['Year']>=1984]
                     [(olympicData['Medal']=='Gold')|
                            (olympicData['Medal']=='Silver')|
                           (olympicData['Medal']=='Bronze')]
                    [olympicData['Sport'] =='Taekwondo']
                    [olympicData['Sex'] == 'F'])

#44
BeachVolleyball_F_win= pd.DataFrame(olympicData[["NOC", "Year","Sex","Sport","Medal","Height","Weight"]]
                     [olympicData['Year']>=1984]
                     [(olympicData['Medal']=='Gold')|
                            (olympicData['Medal']=='Silver')|
                           (olympicData['Medal']=='Bronze')]
                    [olympicData['Sport'] =='Beach Volleyball']
                    [olympicData['Sex'] == 'F'])
#45
Triathlon_F_win= pd.DataFrame(olympicData[["NOC", "Year","Sex","Sport","Medal","Height","Weight"]]
                     [olympicData['Year']>=1984]
                     [(olympicData['Medal']=='Gold')|
                            (olympicData['Medal']=='Silver')|
                           (olympicData['Medal']=='Bronze')]
                    [olympicData['Sport'] =='Triathlon']
                    [olympicData['Sex'] == 'F'])
#46
Softball_F_win= pd.DataFrame(olympicData[["NOC", "Year","Sex","Sport","Medal","Height","Weight"]]
                     [olympicData['Year']>=1984]
                     [(olympicData['Medal']=='Gold')|
                            (olympicData['Medal']=='Silver')|
                           (olympicData['Medal']=='Bronze')]
                    [olympicData['Sport'] =='Softball']
                    [olympicData['Sex'] == 'F'])
#47
Curling_F_win= pd.DataFrame(olympicData[["NOC", "Year","Sex","Sport","Medal","Height","Weight"]]
                     [olympicData['Year']>=1984]
                     [(olympicData['Medal']=='Gold')|
                            (olympicData['Medal']=='Silver')|
                           (olympicData['Medal']=='Bronze')]
                    [olympicData['Sport'] =='Curling']
                    [olympicData['Sex'] == 'F'])
#48
RugbySevens_F_win= pd.DataFrame(olympicData[["NOC", "Year","Sex","Sport","Medal","Height","Weight"]]
                     [olympicData['Year']>=1984]
                     [(olympicData['Medal']=='Gold')|
                            (olympicData['Medal']=='Silver')|
                           (olympicData['Medal']=='Bronze')]
                    [olympicData['Sport'] =='Rugby Sevens']
                    [olympicData['Sex'] == 'F'])
#49
Skeleton_F_win= pd.DataFrame(olympicData[["NOC", "Year","Sex","Sport","Medal","Height","Weight"]]
                     [olympicData['Year']>=1984]
                     [(olympicData['Medal']=='Gold')|
                            (olympicData['Medal']=='Silver')|
                           (olympicData['Medal']=='Bronze')]
                    [olympicData['Sport'] =='Skeleton']
                    [olympicData['Sex'] == 'F'])
#50
Trampolining_F_win= pd.DataFrame(olympicData[["NOC", "Year","Sex","Sport","Medal","Height","Weight"]]
                     [olympicData['Year']>=1984]
                     [(olympicData['Medal']=='Gold')|
                            (olympicData['Medal']=='Silver')|
                           (olympicData['Medal']=='Bronze')]
                    [olympicData['Sport'] =='Trampolining']
                    [olympicData['Sex'] == 'F'])
#51
Golf_F_win= pd.DataFrame(olympicData[["NOC", "Year","Sex","Sport","Medal","Height","Weight"]]
                     [olympicData['Year']>=1984]
                     [(olympicData['Medal']=='Gold')|
                            (olympicData['Medal']=='Silver')|
                           (olympicData['Medal']=='Bronze')]
                    [olympicData['Sport'] =='Golf']
                    [olympicData['Sex'] == 'F'])

# %%
data_Female_Height =[Atheletics_F_win['Height'],Swimming_F_win['Height'],Gymnastics_F_win['Height'],
               CrossCountrySkilling_F_win['Height'],AlpineSkiing_F_win['Height'],Cycling_F_win['Height'],
               Rowing_F_win['Height'],Shooting_F_win['Height'],Biathlon_F_win['Height'],
               Canoeing_F_win['Height'],Sailing_F_win['Height'],Fencing_F_win['Height'],
           
              Football_F_win['Height'],IceHockey_F_win['Height'], Judo_F_win['Height'],
           Wrestling_F_win['Height'],SpeedSkating_F_win['Height'],Hockey_F_win['Height'],
           Equestrianism_F_win['Height'],Boxing_F_win['Height'],Handball_F_win['Height'],
           Basketball_F_win['Height'],Volleyball_F_win['Height'],Weightlifting_F_win['Height'],
           
           Tennis_F_win['Height'],TableTennis_F_win['Height'],WaterPolo_F_win['Height'],
           Archery_F_win['Height'],Bobsleigh_F_win['Height'],ShortTrackSpeedSkating_F_win['Height'],
           
           SkiJumping_F_win['Height'],Badminton_F_win['Height'],Diving_F_win['Height'],
           FigureSkating_F_win['Height'],Luge_F_win['Height'],FreestyleSkiing_F_win['Height'],
           Snowboading_F_win['Height'],SynchronizedSwimming_F_win['Height'],Baseball_F_win['Height'],
        
           NordicCombined_F_win['Height'],MordernPentathlon_F_win['Height'],RhythmicGymnastics_F_win['Height'],
          Taekwondo_F_win['Height'],BeachVolleyball_F_win['Height'],Triathlon_F_win['Height'],
          Softball_F_win['Height'],Curling_F_win['Height'],RugbySevens_F_win['Height'],
          Skeleton_F_win['Height'],Trampolining_F_win['Height'],Golf_F_win['Height']]

Sportlist = ['Atheletics','Swimming','Gymnastics',
               'CrossCountrySkilling','AlpineSkiing','Cycling',
                'Rowing','Shooting','Biathulon',
                'Canoeing','Sailing', 'Fencing','Football','IceHockey','Judo','Wrestling','SpeedSkating',
               'Hockey','Equestrianism','Boxing','Handball',
           'Basketball','Volleyball','Weightlifting',
           
               'Tennis','Table Tennis','Water Polo','Archery',
              'Bobsleigh','Short Track Speed Skating',
            'SkiJumping','Badminton','Diving','FigureSkating','Luge','FreestyleSkiing','Snowboading',
           'SynchronizedSwimming','Baseball',
           
             'NordicCombined','MordernPentathlon','RhythmicGymnastics','Taekwondo','BeachVolleyball',
             'Triathlon','Softball','Curling','RugbySevens','Skeleton','Trampolining','Golf']

# %%
from numpy import * 

N =51# Number of boxes

# generate an array of rainbow colors by fixing the saturation and lightness of the HSL representation of colour 
# and marching around the hue. 
# Plotly accepts any CSS color format, see e.g. http://www.w3schools.com/cssref/css_colors_legal.asp.
c = ['hsl('+str(h)+',50%'+',50%)' for h in linspace(0, 360, N)]

# Each box is represented by a dict that contains the data, the type, and the colour. 
# Use list comprehension to describe N boxes, each with a different colour and with different randomly generated data:
data_F_H = [{
    'y': data_Female_Height[i], 
    'type':'box',
    'marker':{'color': c[i]},
    'name': Sportlist[i]
    } for i in range(int(N))]

# format the layout

layout_F_H = {'xaxis': {'showgrid':True,'zeroline':False, 'tickangle':30,'showticklabels':False},
          'yaxis': {'zeroline':False,'gridcolor':'white'},
          'paper_bgcolor': 'rgb(233,233,233)',
          'plot_bgcolor': 'rgb(233,233,233)',
          'title': 'Female Height Across Sports',
          'width' :900,
          'height' : 600
          }


fig_F_H = go.Figure(data=data_F_H , layout=layout_F_H)

py.iplot(fig_F_H)

# %%
data_Female_Weight =[Atheletics_F_win['Weight'],Swimming_F_win['Weight'],Gymnastics_F_win['Weight'],
               CrossCountrySkilling_F_win['Weight'],AlpineSkiing_F_win['Weight'],Cycling_F_win['Weight'],
               Rowing_F_win['Weight'],Shooting_F_win['Weight'],Biathlon_F_win['Weight'],
               Canoeing_F_win['Weight'],Sailing_F_win['Weight'],Fencing_F_win['Weight'],
           
              Football_F_win['Weight'],IceHockey_F_win['Weight'], Judo_F_win['Weight'],
           Wrestling_F_win['Weight'],SpeedSkating_F_win['Weight'],Hockey_F_win['Weight'],
           Equestrianism_F_win['Weight'],Boxing_F_win['Weight'],Handball_F_win['Weight'],
           Basketball_F_win['Weight'],Volleyball_F_win['Weight'],Weightlifting_F_win['Weight'],
           
           Tennis_F_win['Weight'],TableTennis_F_win['Weight'],WaterPolo_F_win['Weight'],
           Archery_F_win['Weight'],Bobsleigh_F_win['Weight'],ShortTrackSpeedSkating_F_win['Weight'],
           
           SkiJumping_F_win['Weight'],Badminton_F_win['Weight'],Diving_F_win['Weight'],
           FigureSkating_F_win['Weight'],Luge_F_win['Weight'],FreestyleSkiing_F_win['Weight'],
           Snowboading_F_win['Weight'],SynchronizedSwimming_F_win['Weight'],Baseball_F_win['Weight'],
        
           NordicCombined_F_win['Weight'],MordernPentathlon_F_win['Weight'],RhythmicGymnastics_F_win['Weight'],
          Taekwondo_F_win['Weight'],BeachVolleyball_F_win['Weight'],Triathlon_F_win['Weight'],
          Softball_F_win['Weight'],Curling_F_win['Weight'],RugbySevens_F_win['Weight'],
          Skeleton_F_win['Weight'],Trampolining_F_win['Weight'],Golf_F_win['Weight']]

# %%
N =51# Number of boxes

# generate an array of rainbow colors by fixing the saturation and lightness of the HSL representation of colour 
# and marching around the hue. 
# Plotly accepts any CSS color format, see e.g. http://www.w3schools.com/cssref/css_colors_legal.asp.
c = ['hsl('+str(h)+',50%'+',50%)' for h in linspace(0, 360, N)]

# Each box is represented by a dict that contains the data, the type, and the colour. 
# Use list comprehension to describe N boxes, each with a different colour and with different randomly generated data:
data_F_W = [{
    'y': data_Female_Weight[i], 
    'type':'box',
    'marker':{'color': c[i]},
    'name': Sportlist[i]
    } for i in range(int(N))]

# format the layout

layout_F_W = {'xaxis': {'showgrid':True,'zeroline':False, 'tickangle':30,'showticklabels':False},
          'yaxis': {'zeroline':False,'gridcolor':'white'},
          'paper_bgcolor': 'rgb(233,233,233)',
          'plot_bgcolor': 'rgb(233,233,233)',
          'title': 'Female Weight Across Sports',
          'width' :900,
          'height' : 600
          }


fig_F_W= go.Figure(data=data_F_W , layout=layout_F_W)

py.iplot(fig_F_W)

# %%
# Import essential models and functions from sklearn
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
mean_height = []
mean_weight = []
predicted_weight = []

# %%
def linear_Regression_function (Frame):
    Frame.dropna(inplace = True)
    FrameA = pd.DataFrame(Frame['Height'])
    FrameB = pd.DataFrame(Frame['Weight'])
    X_train, X_test, y_train, y_test = train_test_split(FrameA, FrameB, test_size = 0.25)
    linreg = LinearRegression() 
    linreg.fit(X_train, y_train)    

    print('Intercept of Regression \t: b = ', linreg.intercept_)
    print('Coefficients of Regression \t: a = ', linreg.coef_)
    print()

    y_train_pred = linreg.predict(X_train)
    y_test_pred = linreg.predict(X_test)


    print("Goodness of Fit of Model \tTrain Dataset")
    print("Explained Variance (R^2) \t:", linreg.score(X_train, y_train))
    print("Mean Squared Error (MSE) \t:", mean_squared_error(y_train, y_train_pred))
    print()

    print("Goodness of Fit of Model \tTest Dataset")
    print("Explained Variance (R^2) \t:", linreg.score(X_test, y_test))
    print("Mean Squared Error (MSE) \t:", mean_squared_error(y_test, y_test_pred))
    print()

    f, axes = plt.subplots(1, 2, figsize=(10,5))

    axes[0].scatter(y_train, y_train_pred, color = "blue")
    axes[0].plot(y_train, y_train, 'w-', linewidth = 1)
    axes[0].set_xlabel("True values of the Response Variable (Train)")
    axes[0].set_ylabel("Predicted values of the Response Variable (Train)")

    axes[1].scatter(y_test, y_test_pred, color = "green")
    axes[1].plot(y_test, y_test, 'w-', linewidth = 1)
    axes[1].set_xlabel("True values of the Response Variable (Test)")
    axes[1].set_ylabel("Predicted values of the Response Variable (Test)")
    
    return float(linreg.coef_ )* float(statistics.mean(element['Height'])) +  float(linreg.intercept_)

# %%
LinearRegressionDataSet= [Atheletics_F_win_Data,    Swimming_F_win,    Gymnastics_F_win,   CrossCountrySkilling_F_win,  AlpineSkiing_F_win,
Cycling_F_win,                Rowing_F_win,        Shooting_F_win,       Biathlon_F_win,                    Canoeing_F_win,
Sailing_F_win,                 Fencing_F_win,       Football_F_win,         IceHockey_F_win,                Judo_F_win,

             SpeedSkating_F_win,    Hockey_F_win,     Equestrianism_F_win,          
Handball_F_win,              Basketball_F_win,        Volleyball_F_win,           
       WaterPolo_F_win,                             ShortTrackSpeedSkating_F_win,
           

   SynchronizedSwimming_F_win,  


 Softball_F_win,              Curling_F_win,           
]

# %%
LinearRegressionDataSet_String= ['Atheletics_F_win_Data',    'Swimming_F_win',    'Gymnastics_F_win',   
                                 'CrossCountrySkilling_F_win',  'AlpineSkiing_F_win', 'Cycling_F_win', 'Rowing_F_win',        
                                 'Shooting_F_win',       'Biathlon_F_win',                    'Canoeing_F_win',
                                'Sailing_F_win',                 'Fencing_F_win',       'Football_F_win',         
                                 'IceHockey_F_win',                'Judo_F_win', 'SpeedSkating_F_win',    'Hockey_F_win',     
                                 'Equestrianism_F_win',       'Handball_F_win',      'Basketball_F_win',        'Volleyball_F_win',           
                               'WaterPolo_F_win',     'ShortTrackSpeedSkating_F_win','SynchronizedSwimming_F_win',  
                            'Softball_F_win',              'Curling_F_win']

# %%
for element in LinearRegressionDataSet:
        prd_weight = linear_Regression_function(element)
        mean_height.append(statistics.mean(element['Height']))
        mean_weight.append(statistics.mean(element['Weight']))
        predicted_weight.append(prd_weight)

# %%
table_h_w= pd.DataFrame({
    'Sports': LinearRegressionDataSet_String,
    'Mean Height':mean_height,
    'Mean Weight':mean_weight,
    'Predicted Weight': predicted_weight 
})

# %%
table_h_w
